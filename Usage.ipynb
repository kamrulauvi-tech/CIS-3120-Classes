# %%
from Animal import Animal

# %%
x = Animal("Joe", "Dog", 5, "Woof!")
x.talk()
x.eat()
x.sleep()
x.play()
x.run("fast")
x.grow_older()
x.change_sound("Bark!")
x.describe()
# Out:
# Joe says: Woof!
# Joe is eating food.
# Joe is sleeping for 8 hours.
# Joe is playing happily!
# Joe is running fast!
# Joe is now 6 years old!
# Joe now makes this sound: Bark!
# Name: Joe, Species: Dog, Age: 6, Sound: Bark!
